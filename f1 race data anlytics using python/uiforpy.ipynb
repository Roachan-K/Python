# %%
import pandas as pd
import tkinter as tk
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tkinter import *
import tkinter.messagebox
from PIL import Image, ImageTk

window=Tk()
window.title('Formula One Race Analysis')
window.geometry("1000x7000+500+200")
window.configure(bg="#1C1C1C")


h1 = Label(text = "Formula One Race Analysis",font=('Times new Roman',30,'bold'),bg="#1C1C1C",fg="#FFD700")
h1.place(x=570, y=25)

def resize_func():
    image = Image.open("car.png")
    w = int(width.get())
    h = int(height.get())
    resize_img = image.resize((w, h))
    img = ImageTk.PhotoImage(resize_img)
    disp_img.config(image=img)
    disp_img.image = img


frame = Frame(window, bg="#1C1C1C")
frame.pack()

Label(
    frame,
    text='Width', bg="#1C1C1C", fg="#FFD700"
    ).pack(side=LEFT)
width = Entry(frame, width=50)
width.insert(END, 1600)
width.pack(side=LEFT)

Label(
    frame,
    text='Height', bg="#1C1C1C", fg="#FFD700"
    ).pack(side=LEFT)

height = Entry(frame, width=50)
height.insert(END, 800)
height.pack(side=LEFT)

resize_btn = Button(
    frame,
    text='Resize',
    command=resize_func, bg="#FFD700", fg="#1C1C1C",
)
resize_btn.pack(side=LEFT)

disp_img = Label()
disp_img.place(x=0,y=70)




def func():#function of the button
    tkinter.messagebox.showinfo("message","data is loadded")

data = pd.read_csv(r"results.csv")

def function():
	
	label = df
	top = Toplevel()
	top.title("DATA")
	msg = Label(top,text=label)
	msg.pack()
	but = Button(top,width=20,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()

    
data = pd.read_csv(r"races.csv")
run = data.info()


def datatype():
	label = data.head(6)
	top = Toplevel()
	top.title("DATA HEAD")
	msg= Label(top,text=label)
	msg.pack()
	but = Button(top,width=20,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()

    
def  regression_plot(): 
	global image
	top = Toplevel()
	top.title("Formula one data")
	image = ImageTk.PhotoImage(Image.open("screen5.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()  
    
def Hamilton_Heatmap(): 
	global image
	top = Toplevel()
	top.title("Hamilton_Heatmap")
	image = ImageTk.PhotoImage(Image.open("hamiltonheatpath.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()  
    
def Most_GP_Winners_in_F1():
	global image
	top = Toplevel()
	top.title("Formula one data")
	image = ImageTk.PhotoImage(Image.open("screen1.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack() 
    
def AAL_STOCK_PREDICTION():
	global image
	top = Toplevel()
	top.title("Formula One data")
	image = ImageTk.PhotoImage(Image.open("screen2.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()
    
def MOST_WINS_FOR_CONSTRUCTOR():
	global image
	top = Toplevel()
	top.title("MOST_WINS_FOR_CONSTRUCTOR")
	image = ImageTk.PhotoImage(Image.open("screen3.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()
    
def y2023_TIMES_FOR_ALL_DRIVERS():
	global image
	top = Toplevel()
	top.title("2023 TIMES FOR ALL DRIVERS")
	image = ImageTk.PhotoImage(Image.open("screen7.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()   

def Average_lap_speed_perlap():
	global image
	top = Toplevel()
	top.title("Average_lap_speed_perlap")
	image = ImageTk.PhotoImage(Image.open("screen6.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()

def top_ten_f1_wins():
	global image
	top = Toplevel()
	top.title("top_ten_f1_wins")
	image = ImageTk.PhotoImage(Image.open("screen2.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()

def micheal_schumaker():
	global image
	top = Toplevel()
	top.title("MOST_WINS_FOR_CONSTRUCTOR")
	image = ImageTk.PhotoImage(Image.open("michael_schumacher.png"))
	msg = Label(top,image=image)
	msg.pack()
	but = Button(top,width=10,height=3,bg="red",text="Exit",command=top.destroy,font=("comic sans",10))
	but.pack()

button1 = tk.Button( width=30,height=3,bg="#FFD700",fg="black",text="Load Data", command=func, font=('Times new Roman',12,'bold'))
button1.pack()
button1.place(x=30,y=110)

button2 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Most GP Winners in F1", command=Most_GP_Winners_in_F1,font=('Times new Roman',12,'bold'))
button2.pack()
button2.place(x=30,y=280)

button3 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Print Data Head", command=datatype,font=('Times new Roman',12,'bold'))
button3.pack()
button3.place(x=30,y=190)

button4 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Regression Plot", command=regression_plot,font=('Times new Roman',12,'bold'))
button4.pack()
button4.place(x=1200,y=190)

button5 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Hamilton Heatmap", command=Hamilton_Heatmap,font=('Times new Roman',12,'bold'))
button5.pack()
button5.place(x=1200,y=280)

button6 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Most Wins For Constructors", command=MOST_WINS_FOR_CONSTRUCTOR,font=('Times new Roman',12,'bold'))
button6.pack()
button6.place(x=30,y=460)


button7 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="2023 Lap Times For All Drivers", command=y2023_TIMES_FOR_ALL_DRIVERS,font=('Times new Roman',12,'bold'))
button7.pack()
button7.place(x=1200,y=460)


button8 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Average Lap Speed Per Year", command=Average_lap_speed_perlap,font=('Times new Roman',12,'bold'))
button8.pack()
button8.place(x=1200,y=110)

button9 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Top Ten F1 Wins", command=top_ten_f1_wins,font=('Times new Roman',12,'bold'))
button9.pack()
button9.place(x=30,y=370)

button10 = tk.Button(width=30,height=3,bg="#FFD700",fg="black", text="Micheal Schumaker ", command=micheal_schumaker,font=('Times new Roman',12,'bold'))
button10.pack()
button10.place(x=1200,y=370)

    
window.mainloop()
# Out:
# C:\Users\roach\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     1101 non-null   int64
#  1   year       1101 non-null   int64
#  2   round      1101 non-null   int64
#  3   circuitId  1101 non-null   int64
#  4   name       1101 non-null   object
#  5   date       1101 non-null   object
#  6   time       1101 non-null   object
#  7   url        1101 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 68.9+ KB
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\roach\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
# ...
